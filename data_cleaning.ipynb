# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('top5leagues.csv')
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0                 Rk             Player             Nation                Pos
# 1                  1         Max Aarons            eng ENG                 DF
# 2                  2  Joshua Acheampong            eng ENG                 DF
# 3                  3        Tyler Adams             us USA                 MF
# 4                  4   Tosin Adarabioyo            eng ENG                 DF
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
# 0              Squad                Age               Born                90s
# 1        Bournemouth                 23               2000               13.7
# 2            Chelsea                 17               2006                0.1
# 3        Bournemouth                 24               1999                1.3
# 4             Fulham                 25               1997               18.0
#
# ...

# %%
df.isnull().sum()
df['Unnamed: 1_level_0'].duplicated().sum()
duplicates=df[df.duplicated(subset=['Unnamed: 1_level_0'], keep=False)]
#print(duplicates)
print(duplicates['Unnamed: 1_level_0'].unique())
# Out:
# ['Player' 'Cameron Archer' 'Armando Broja' 'Alex Iwobi' 'Brennan Johnson'
#  'Neal Maupay' 'James Mcatee' 'Matheus Nunes' 'Cole Palmer'
#  'Kalvin Phillips' 'Sergio Reguilón']

# %%
df.drop_duplicates(subset=['Unnamed: 1_level_0'])

# %%
duplicates = df[df['Unnamed: 1_level_0'].isin(duplicates['Unnamed: 1_level_0'].unique())]
duplicates.tail(20)
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 351                338       James Mcatee            eng ENG
# 352                339       James Mcatee            eng ENG
# 364                 Rk             Player             Nation
# 390                 Rk             Player             Nation
# 399                384      Matheus Nunes             pt POR
# 400                385      Matheus Nunes             pt POR
# 416                 Rk             Player             Nation
# 430                414        Cole Palmer            eng ENG
# 431                415        Cole Palmer            eng ENG
# 442                 Rk             Player             Nation
# 444                427    Kalvin Phillips            eng ENG
# 445                428    Kalvin Phillips            eng ENG
# 462                445    Sergio Reguilón             es ESP
# 463                446    Sergio Reguilón             es ESP
# ...
