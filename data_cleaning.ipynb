# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('top5leagues.csv')
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0                 Rk             Player             Nation                Pos
# 1                  1         Max Aarons            eng ENG                 DF
# 2                  2  Joshua Acheampong            eng ENG                 DF
# 3                  3        Tyler Adams             us USA                 MF
# 4                  4   Tosin Adarabioyo            eng ENG                 DF
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
# 0              Squad                Age               Born                90s
# 1        Bournemouth                 23               2000               13.7
# 2            Chelsea                 17               2006                0.1
# 3        Bournemouth                 24               1999                1.3
# 4             Fulham                 25               1997               18.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0_level_0       0
# Unnamed: 1_level_0       0
# Unnamed: 2_level_0       0
# Unnamed: 3_level_0       0
# Unnamed: 4_level_0       0
# Unnamed: 5_level_0       0
# Unnamed: 6_level_0       0
# Unnamed: 7_level_0       0
# Standard                 0
# Standard.1               0
# Standard.2               0
# Standard.3             115
# Standard.4               0
# Standard.5               0
# Standard.6             115
# Standard.7             178
# Standard.8             115
# Standard.9               0
# Standard.10              0
# Standard.11              0
# Expected                 0
# Expected.1               0
# Expected.2             115
# Expected.3               0
# Expected.4               0
# Unnamed: 25_level_0      0
# dtype: int64

# %%
df1=df.iloc[[0,1]]
df1.describe()
# Out:
#        Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# count                   2                  2                  2
# unique                  2                  2                  2
# top                    Rk             Player             Nation
# freq                    1                  1                  1
#
#        Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
# count                   2                  2                  2
# unique                  2                  2                  2
# top                   Pos              Squad                Age
# freq                    1                  1                  1
#
#        Unnamed: 6_level_0 Unnamed: 7_level_0 Standard Standard.1  ...  \
# count                   2                  2        2          2  ...
# unique                  2                  2        2          2  ...
# top                  Born                90s      Gls         Sh  ...
# ...
